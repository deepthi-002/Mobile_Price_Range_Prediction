# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\wecome\Documents\Verzeo\mobile_price_range_data.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
df['price_range'].nunique()
# Out:
# 4

# %%
df.corr()['price_range']
# Out:
# battery_power    0.200723
# blue             0.020573
# clock_speed     -0.006606
# dual_sim         0.017444
# fc               0.021998
# four_g           0.014772
# int_memory       0.044435
# m_dep            0.000853
# mobile_wt       -0.030302
# n_cores          0.004399
# pc               0.033599
# px_height        0.148858
# px_width         0.165818
# ram              0.917046
# sc_h             0.022986
# sc_w             0.038711
# talk_time        0.021859
# three_g          0.023611
# touch_screen    -0.030411
# wifi             0.018785
# price_range      1.000000
# Name: price_range, dtype: float64

# %%
high_corr = df.corr()['price_range'] > 0.40

# %%
high_corr
# Out:
# battery_power    False
# blue             False
# clock_speed      False
# dual_sim         False
# fc               False
# four_g           False
# int_memory       False
# m_dep            False
# mobile_wt        False
# n_cores          False
# pc               False
# px_height        False
# px_width         False
# ram               True
# sc_h             False
# sc_w             False
# talk_time        False
# three_g          False
# touch_screen     False
# wifi             False
# price_range       True
# Name: price_range, dtype: bool

# %% [markdown]
# Check Missing Values

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# EDA - Exploratory Data Analysis

# %%
sns.barplot(x='price_range', y='ram', data=df,hue='three_g')
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %%
sns.barplot(x='price_range', y='ram', data=df, hue="touch_screen")
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %%
sns.barplot(x='price_range', y='ram', data=df)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %%
sns.scatterplot(x='px_height', y='battery_power', data=df, hue='ram')
# Out:
# <AxesSubplot:xlabel='px_height', ylabel='battery_power'>

# %%
sns.scatterplot(x='px_width', y='battery_power', data=df, hue='ram')
# Out:
# <AxesSubplot:xlabel='px_width', ylabel='battery_power'>

# %%
sns.scatterplot(x='px_height', y='battery_power', data=df, hue='wifi')
# Out:
# <AxesSubplot:xlabel='px_height', ylabel='battery_power'>

# %%
sns.boxplot(x='price_range',y='ram',data=df,hue='wifi')
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %%
sns.violinplot(x='price_range',y='ram',data=df,hue='touch_screen')
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %%
sns.scatterplot(x='battery_power', y='int_memory', data=df, hue='blue')
# Out:
# <AxesSubplot:xlabel='battery_power', ylabel='int_memory'>

# %%
df['ram']
# Out:
# 0       2549
# 1       2631
# 2       2603
# 3       2769
# 4       1411
#         ...
# 1995     668
# 1996    2032
# 1997    3057
# 1998     869
# 1999    3919
# Name: ram, Length: 2000, dtype: int64

# %%
X = df.drop('price_range',axis=1)
y = df['price_range']

# %% [markdown]
# Train-Test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (1400, 20)

# %%
y_train.shape
# Out:
# (1400,)

# %%
X_test.shape
# Out:
# (600, 20)

# %%
y_test.shape
# Out:
# (600,)

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()

# %%
model1.fit(X_train,y_train)
# Out:
# C:\Users\wecome\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred1 = model1.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print("The Accuracy Score is",accuracy_score(y_pred1,y_test))
print("\n")
print("The Classification report is",classification_report(y_pred1,y_test))
print("\n")
print("The Confusion matrix is",confusion_matrix(y_pred1,y_test))
# Out:
# The Accuracy Score is 0.625
#
#
# The Classification report is               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       137
#            1       0.57      0.54      0.56       150
#            2       0.42      0.54      0.47       138
#            3       0.77      0.61      0.68       175
#
#     accuracy                           0.62       600
#    macro avg       0.64      0.63      0.63       600
# weighted avg       0.65      0.62      0.63       600
#
#
#
# The Confusion matrix is [[114  23   0   0]
#  [ 28  81  40   1]
#  [  2  32  74  30]
#  [  0   5  64 106]]

# %%
from sklearn.svm import SVC
model2 = SVC(kernel='rbf')
model2.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred2 = model2.predict(X_test)

# %%
y_pred2
# Out:
# array([1, 1, 2, 1, 1, 1, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 1, 2, 0, 1, 3, 0,
#        2, 3, 2, 2, 2, 2, 0, 0, 2, 3, 0, 0, 3, 0, 0, 0, 1, 1, 1, 2, 3, 2,
#        3, 0, 1, 3, 3, 1, 0, 0, 2, 3, 3, 2, 0, 3, 2, 3, 2, 2, 3, 1, 3, 1,
#        0, 0, 0, 2, 1, 2, 3, 2, 1, 3, 3, 2, 0, 2, 0, 0, 2, 1, 2, 2, 2, 1,
#        0, 0, 3, 2, 0, 2, 0, 3, 2, 0, 2, 3, 0, 1, 2, 3, 0, 2, 0, 0, 2, 0,
#        1, 0, 3, 2, 2, 1, 1, 3, 1, 0, 3, 3, 2, 3, 1, 3, 3, 2, 1, 1, 1, 0,
#        0, 1, 0, 2, 3, 0, 2, 3, 1, 3, 0, 0, 0, 1, 1, 2, 2, 0, 3, 1, 2, 2,
#        3, 2, 2, 0, 3, 2, 2, 2, 2, 2, 1, 2, 1, 1, 3, 3, 1, 2, 0, 3, 1, 3,
#        2, 2, 3, 2, 2, 1, 0, 1, 2, 2, 1, 2, 0, 3, 1, 0, 2, 2, 0, 2, 0, 0,
#        3, 0, 0, 1, 3, 2, 1, 3, 0, 2, 2, 2, 1, 1, 1, 3, 1, 3, 1, 0, 3, 1,
#        1, 2, 3, 0, 2, 3, 3, 0, 3, 1, 1, 1, 0, 2, 1, 2, 1, 2, 2, 0, 1, 2,
#        1, 2, 0, 3, 3, 2, 3, 3, 1, 3, 1, 1, 3, 1, 0, 2, 0, 0, 1, 3, 3, 0,
#        1, 0, 1, 1, 0, 2, 3, 0, 3, 2, 1, 2, 1, 2, 1, 2, 1, 3, 1, 2, 3, 2,
# ...

# %%
print("The Accuracy Score is",accuracy_score(y_pred2,y_test))
print("\n")
print("The Classification report is",classification_report(y_pred2,y_test))
print("\n")
print("The Confusion matrix is",confusion_matrix(y_pred2,y_test))
# Out:
# The Accuracy Score is 0.945
#
#
# The Classification report is               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       147
#            1       0.96      0.89      0.92       151
#            2       0.90      0.95      0.92       168
#            3       0.95      0.97      0.96       134
#
#     accuracy                           0.94       600
#    macro avg       0.95      0.95      0.95       600
# weighted avg       0.95      0.94      0.95       600
#
#
#
# The Confusion matrix is [[142   5   0   0]
#  [  2 135  14   0]
#  [  0   1 160   7]
#  [  0   0   4 130]]

# %%
model2 = SVC(kernel='linear')

# %%
model2.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred3 = model2.predict(X_test)

# %%
y_pred3
# Out:
# array([1, 1, 2, 1, 0, 1, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 2, 0, 1, 3, 1,
#        2, 3, 2, 2, 2, 2, 0, 0, 2, 3, 0, 0, 3, 0, 0, 0, 1, 1, 1, 2, 3, 2,
#        3, 0, 1, 3, 3, 1, 0, 0, 2, 3, 3, 2, 0, 3, 2, 3, 2, 2, 3, 1, 3, 1,
#        0, 0, 0, 2, 1, 2, 3, 2, 2, 3, 3, 2, 0, 2, 0, 0, 2, 1, 2, 2, 2, 1,
#        0, 0, 3, 2, 0, 2, 0, 3, 2, 0, 2, 3, 0, 1, 3, 3, 0, 2, 0, 0, 2, 0,
#        1, 0, 3, 2, 2, 1, 1, 3, 1, 0, 3, 3, 2, 3, 1, 3, 3, 2, 1, 1, 1, 0,
#        0, 1, 0, 1, 3, 0, 2, 3, 1, 3, 0, 0, 0, 1, 1, 2, 2, 0, 3, 1, 2, 2,
#        3, 2, 2, 0, 3, 2, 2, 2, 2, 2, 1, 2, 1, 1, 3, 3, 1, 2, 0, 3, 1, 3,
#        2, 2, 3, 2, 2, 1, 0, 1, 3, 2, 1, 2, 0, 3, 1, 0, 2, 2, 0, 2, 0, 0,
#        3, 0, 0, 1, 3, 2, 1, 3, 0, 3, 2, 2, 1, 2, 1, 3, 1, 3, 1, 0, 3, 1,
#        2, 2, 3, 0, 2, 3, 3, 0, 3, 1, 1, 1, 0, 2, 1, 2, 1, 2, 1, 0, 1, 2,
#        1, 2, 0, 3, 3, 2, 3, 3, 2, 2, 1, 2, 3, 1, 0, 2, 0, 1, 1, 3, 3, 0,
#        1, 0, 2, 1, 0, 2, 3, 1, 3, 2, 1, 2, 2, 2, 0, 3, 1, 3, 1, 2, 3, 2,
# ...

# %%
print("The Accuracy Score is",accuracy_score(y_pred3,y_test))
print("\n")
print("The Classification report is",classification_report(y_pred3,y_test))
print("\n")
print("The Confusion matrix is",confusion_matrix(y_pred3,y_test))
# Out:
# The Accuracy Score is 0.9716666666666667
#
#
# The Classification report is               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       145
#            1       0.97      0.95      0.96       144
#            2       0.94      0.97      0.95       172
#            3       0.99      0.97      0.98       139
#
#     accuracy                           0.97       600
#    macro avg       0.97      0.97      0.97       600
# weighted avg       0.97      0.97      0.97       600
#
#
#
# The Confusion matrix is [[144   1   0   0]
#  [  0 137   7   0]
#  [  0   3 167   2]
#  [  0   0   4 135]]

# %%
from sklearn.neighbors import KNeighborsClassifier
model3 = KNeighborsClassifier(n_neighbors=15,metric='euclidean')

# %%
model3.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=15)

# %%
y_pred4 = model3.predict(X_test)

# %%
y_pred4
# Out:
# array([1, 1, 2, 1, 0, 1, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 1, 2, 1, 1, 3, 0,
#        2, 3, 2, 2, 2, 2, 0, 0, 2, 3, 0, 0, 3, 0, 0, 0, 1, 1, 1, 2, 2, 2,
#        3, 0, 1, 3, 3, 1, 0, 0, 2, 3, 3, 2, 0, 3, 2, 3, 2, 2, 3, 1, 3, 1,
#        0, 0, 0, 2, 1, 2, 3, 2, 1, 3, 3, 2, 0, 2, 0, 0, 2, 1, 2, 2, 2, 1,
#        0, 0, 3, 2, 0, 2, 0, 3, 2, 0, 2, 3, 0, 1, 2, 3, 0, 2, 0, 0, 2, 0,
#        1, 0, 3, 2, 2, 2, 1, 3, 1, 0, 3, 3, 2, 3, 1, 3, 3, 2, 1, 1, 1, 0,
#        0, 1, 0, 2, 3, 0, 2, 3, 1, 3, 0, 0, 0, 1, 1, 2, 2, 0, 3, 1, 3, 2,
#        3, 2, 2, 0, 3, 1, 2, 2, 2, 2, 1, 2, 1, 1, 3, 3, 1, 2, 0, 3, 1, 3,
#        2, 2, 3, 2, 2, 1, 0, 1, 2, 2, 1, 2, 0, 3, 1, 0, 2, 2, 0, 2, 0, 0,
#        3, 0, 0, 1, 3, 2, 1, 3, 0, 2, 2, 2, 1, 1, 1, 3, 1, 3, 0, 0, 3, 1,
#        1, 2, 3, 0, 2, 3, 3, 0, 3, 1, 1, 1, 0, 2, 1, 2, 1, 2, 2, 0, 1, 2,
#        1, 2, 0, 3, 3, 2, 3, 3, 1, 3, 1, 1, 3, 1, 0, 2, 0, 1, 1, 3, 3, 0,
#        1, 0, 1, 1, 0, 2, 3, 1, 3, 2, 1, 2, 1, 2, 0, 3, 2, 3, 1, 2, 3, 2,
# ...

# %%
print("The Accuracy Score is",accuracy_score(y_pred4,y_test))
print("\n")
print("The Classification report is",classification_report(y_pred4,y_test))
print("\n")
print("The Confusion matrix is",confusion_matrix(y_pred4,y_test))
# Out:
# The Accuracy Score is 0.9316666666666666
#
#
# The Classification report is               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       148
#            1       0.94      0.89      0.91       149
#            2       0.88      0.93      0.90       169
#            3       0.93      0.96      0.94       134
#
#     accuracy                           0.93       600
#    macro avg       0.93      0.93      0.93       600
# weighted avg       0.93      0.93      0.93       600
#
#
#
# The Confusion matrix is [[142   6   0   0]
#  [  2 132  15   0]
#  [  0   3 157   9]
#  [  0   0   6 128]]

# %% [raw]
# Accuracy of the Models
# Model1 - LogisticRegression                          - 62
# Model2 - SVM(kernel='rbf')                           - 94
# Model3 - SVM(kernel='linear')                        - 97
# Model4 - KNN with 15neighbors and Euclidean Distance - 93

# %%
import pickle

# %%
with open('Best_Model_Mobile','wb') as f:
    pickle.dump(model2,f)

# %%
with open('Best_Model_Mobile', 'rb') as f:
    mm = pickle.load(f)

# %%
mm.predict([[12,221,2,2,1,1,12,21,12,21,54,65,77,89,43,45,76,12,2,45]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# Therefore, it predicted that Linear SVM Model has Best Accuracy with 97.
